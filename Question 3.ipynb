# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_excel('Admission 2019 Data for ISB Campus.xlsx',header = 1)
pd.set_option('display.max_columns',None)
data
# Out:
#              L          CITY  STATUS_ID              STATUS  Ist  2nd  3rd  \
# 0      1900003    Rawalpindi          7     Challan Printed  ISB  NaN  NaN
# 1      1900005         Okara          2        AcademicInfo  NaN  NaN  NaN
# 2      1900006        Lahore          1        PersonalInfo  NaN  NaN  NaN
# 3      1900007      Peshawar         10  Admit Card Printed  PWR  NaN  NaN
# 4      1900008     Islamabad         10  Admit Card Printed  ISB  NaN  NaN
# ...        ...           ...        ...                 ...  ...  ...  ...
# 26368  1932905        Multan          7     Challan Printed  ISB  NaN  NaN
# 26369  1932906        Lahore         10  Admit Card Printed  ISB  NaN  NaN
# 26370  1932908  Bahawalnagar          9           Scheduled  ISB  NaN  NaN
# 26371  1932909      Peshawar         10  Admit Card Printed  PWR  NaN  NaN
# 26372  1932909      Peshawar         10  Admit Card Printed  PWR  NaN  NaN
#
#        4th   Ist.1   2nd.1 3rd.1 4th.1       Board   Degree   Total  Obtained  \
# 0      NaN  BS(AF)     NaN   NaN   NaN   Cambridge  O-Level  1000.0     900.0
# 1      NaN     NaN     NaN   NaN   NaN     Sahiwal      SSC  1100.0    1061.0
# 2      NaN     NaN     NaN   NaN   NaN         NaN      NaN     NaN       NaN
# 3      NaN  BS(EE)  BS(CS)   NaN   NaN     Federal      SSC  1050.0     802.0
# 4      NaN  BS(CS)     NaN   NaN   NaN     Federal      SSC  1050.0     728.0
# ...    ...     ...     ...   ...   ...         ...      ...     ...       ...
# 26368  NaN  BS(CS)     NaN   NaN   NaN      Multan      SSC  1100.0    1018.0
# 26369  NaN  BS(CS)     NaN   NaN   NaN   Cambridge  O-Level   900.0     720.0
# 26370  NaN  BS(EE)     NaN   NaN   NaN  Bahawalpur      SSC  1100.0     924.0
# 26371  NaN  BS(EE)     NaN   NaN   NaN    Peshawar      SSC  1100.0     918.0
# 26372  NaN  BS(EE)     NaN   NaN   NaN    Peshawar      SSC  1100.0     918.0
#
#           Board.1     Degree.1  Total.1  Obtained.1  NTS_MARKS NU_TEST_CENTER  \
# 0         Federal  HSSC (I+II)   1050.0       900.0        NaN            NaN
# 1         Sahiwal       HSSC-I    520.0      1061.0        NaN            NaN
# 2             NaN          NaN      NaN         NaN        NaN            NaN
# 3         Federal  HSSC (I+II)   1100.0       802.0        NaN            ISB
# 4         Federal  HSSC (I+II)   1100.0       728.0       78.0            ISB
# ...           ...          ...      ...         ...        ...            ...
# 26368      Multan  HSSC (I+II)   1100.0      1018.0        NaN            NaN
# 26369   Cambridge      A-Level   1100.0       720.0        NaN            LHR
# 26370  Bahawalpur  HSSC (I+II)   1100.0       924.0        NaN            LHR
# 26371    Peshawar  HSSC (I+II)   1100.0       918.0        NaN            NaN
# 26372    Peshawar  HSSC (I+II)   1100.0       918.0        NaN            NaN
#
#        BBA         BS  Total.2  Obtained.2  Total.3  Obtained.3  \
# 0      NaN        NaN      NaN         NaN      NaN         NaN
# 1      NaN        NaN      NaN         NaN      NaN         NaN
# 2      NaN        NaN      NaN         NaN      NaN         NaN
# 3      NaN  30.291665      NaN         NaN      NaN         NaN
# 4      NaN  47.187499      NaN         NaN      NaN         NaN
# ...    ...        ...      ...         ...      ...         ...
# 26368  NaN        NaN      NaN         NaN      NaN         NaN
# 26369  NaN  41.847224      NaN         NaN      NaN         NaN
# 26370  NaN  52.458334      NaN         NaN      NaN         NaN
# 26371  NaN        NaN      NaN         NaN      NaN         NaN
# 26372  NaN        NaN      NaN         NaN      NaN         NaN
#
#        NTS Merit Marks  BBA/BS(AF)   BS.1 Campus Discipline Campus.1  \
# 0                  NaN         NaN    NaN    NaN        NaN      NaN
# 1                  NaN         NaN    NaN    NaN        NaN      NaN
# 2                  NaN         NaN    NaN    NaN        NaN      NaN
# 3                  NaN         NaN  51.87    NaN        NaN      PWR
# 4                66.91         NaN  51.50    NaN        NaN      NaN
# ...                ...         ...    ...    ...        ...      ...
# 26368              NaN         NaN    NaN    NaN        NaN      NaN
# 26369              NaN         NaN  58.42    NaN        NaN      NaN
# 26370              NaN         NaN  65.59    NaN        NaN      NaN
# 26371              NaN         NaN    NaN    NaN        NaN      NaN
# 26372              NaN         NaN    NaN    NaN        NaN      NaN
#
#       Discipline.1 Campus.2 Discipline.2 DEGREE_STATUS
# 0              NaN      NaN          NaN           NaN
# 1              NaN      NaN          NaN           NaN
# 2              NaN      NaN          NaN           NaN
# 3           BS(EE)      NaN          NaN           NaN
# 4              NaN      NaN          NaN           NaN
# ...            ...      ...          ...           ...
# 26368          NaN      NaN          NaN           NaN
# 26369          NaN      CFD   BS(CS)           Current
# 26370          NaN      ISB   BS(EE)           Current
# 26371          NaN      PWR   BS(EE)         Cancelled
# 26372          NaN      PWR   BS(EE)           Current
#
# [26373 rows x 38 columns]

# %%
df = pd.DataFrame(data)

# %%
df.rename(columns = {'Ist': '1st_campus_pref', '2nd': '2nd_campus_pref','3rd': '3rd_campus_pref','4th': '4th_campus_pref'}, inplace = True)

# %%
df.rename(columns = {'Ist.1': '1st_discpline_pref', '2nd.1': '2nd_discpline_pref','3rd.1': '3rd_discpline_pref','4th.1': '4th_discpline_pref'}, inplace = True)

# %%
df.rename(columns = {'Board': 'Board_Matriculation', 'Degree': 'Degree_Matriculation','Total': 'Total_Matriculation','Obtained': 'Obtained_Matriculation'}, inplace = True)

# %%
df.rename(columns = {'Board.1': 'Board_Intermediate', 'Degree.1': 'Degree_Intermediate','Total.1': 'Total_Intermediate','Obtained.1': 'Obtained_Intermediate'}, inplace = True)

# %%
df.rename(columns = {'Total.2': 'Total_SAT_I','Obtained.2': 'Obtained_SAT_I'}, inplace = True)

# %%
df.rename(columns = {'Total.3': 'Total_SAT_II','Obtained.3': 'Obtained_SAT_II'}, inplace = True)

# %%
df.rename(columns = {'BBA': 'BBA_NU_Test_Marks','BS': 'BS_NU_Test_Marks'}, inplace = True)

# %%
df.rename(columns = {'BBA/BS(AF)': 'BBA/BS(AF)_NU_Merit_Marks','BS.1': 'BS_NU_Merit_Marks'}, inplace = True)

# %%
df.rename(columns = {'Campus.1': 'Campus_NU_Admission_Offer','Discipline.1': 'Discipline_NU_Admission_Offer'}, inplace = True)

# %%
df.rename(columns = {'Campus.2': 'Campus_Admission','Discipline.2': 'Discipline_Admission'}, inplace = True)

# %%
df
# Out:
#              L          CITY  STATUS_ID              STATUS 1st_campus_pref  \
# 0      1900003    Rawalpindi          7     Challan Printed             ISB
# 1      1900005         Okara          2        AcademicInfo             NaN
# 2      1900006        Lahore          1        PersonalInfo             NaN
# 3      1900007      Peshawar         10  Admit Card Printed             PWR
# 4      1900008     Islamabad         10  Admit Card Printed             ISB
# ...        ...           ...        ...                 ...             ...
# 26368  1932905        Multan          7     Challan Printed             ISB
# 26369  1932906        Lahore         10  Admit Card Printed             ISB
# 26370  1932908  Bahawalnagar          9           Scheduled             ISB
# 26371  1932909      Peshawar         10  Admit Card Printed             PWR
# 26372  1932909      Peshawar         10  Admit Card Printed             PWR
#
#       2nd_campus_pref 3rd_campus_pref 4th_campus_pref 1st_discpline_pref  \
# 0                 NaN             NaN             NaN             BS(AF)
# 1                 NaN             NaN             NaN                NaN
# 2                 NaN             NaN             NaN                NaN
# 3                 NaN             NaN             NaN             BS(EE)
# 4                 NaN             NaN             NaN             BS(CS)
# ...               ...             ...             ...                ...
# 26368             NaN             NaN             NaN             BS(CS)
# 26369             NaN             NaN             NaN             BS(CS)
# 26370             NaN             NaN             NaN             BS(EE)
# 26371             NaN             NaN             NaN             BS(EE)
# 26372             NaN             NaN             NaN             BS(EE)
#
#       2nd_discpline_pref 3rd_discpline_pref 4th_discpline_pref  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                 BS(CS)                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 26368                NaN                NaN                NaN
# 26369                NaN                NaN                NaN
# 26370                NaN                NaN                NaN
# 26371                NaN                NaN                NaN
# 26372                NaN                NaN                NaN
#
#       Board_Matriculation Degree_Matriculation  Total_Matriculation  \
# 0               Cambridge              O-Level               1000.0
# 1                 Sahiwal                  SSC               1100.0
# 2                     NaN                  NaN                  NaN
# 3                 Federal                  SSC               1050.0
# 4                 Federal                  SSC               1050.0
# ...                   ...                  ...                  ...
# 26368              Multan                  SSC               1100.0
# 26369           Cambridge              O-Level                900.0
# 26370          Bahawalpur                  SSC               1100.0
# 26371            Peshawar                  SSC               1100.0
# 26372            Peshawar                  SSC               1100.0
#
#        Obtained_Matriculation Board_Intermediate Degree_Intermediate  \
# 0                       900.0            Federal         HSSC (I+II)
# 1                      1061.0            Sahiwal              HSSC-I
# 2                         NaN                NaN                 NaN
# 3                       802.0            Federal         HSSC (I+II)
# 4                       728.0            Federal         HSSC (I+II)
# ...                       ...                ...                 ...
# 26368                  1018.0             Multan         HSSC (I+II)
# 26369                   720.0          Cambridge             A-Level
# 26370                   924.0         Bahawalpur         HSSC (I+II)
# 26371                   918.0           Peshawar         HSSC (I+II)
# 26372                   918.0           Peshawar         HSSC (I+II)
#
#        Total_Intermediate  Obtained_Intermediate  NTS_MARKS NU_TEST_CENTER  \
# 0                  1050.0                  900.0        NaN            NaN
# 1                   520.0                 1061.0        NaN            NaN
# 2                     NaN                    NaN        NaN            NaN
# 3                  1100.0                  802.0        NaN            ISB
# 4                  1100.0                  728.0       78.0            ISB
# ...                   ...                    ...        ...            ...
# 26368              1100.0                 1018.0        NaN            NaN
# 26369              1100.0                  720.0        NaN            LHR
# 26370              1100.0                  924.0        NaN            LHR
# 26371              1100.0                  918.0        NaN            NaN
# 26372              1100.0                  918.0        NaN            NaN
#
#        BBA_NU_Test_Marks  BS_NU_Test_Marks  Total_SAT_I  Obtained_SAT_I  \
# 0                    NaN               NaN          NaN             NaN
# 1                    NaN               NaN          NaN             NaN
# 2                    NaN               NaN          NaN             NaN
# 3                    NaN         30.291665          NaN             NaN
# 4                    NaN         47.187499          NaN             NaN
# ...                  ...               ...          ...             ...
# 26368                NaN               NaN          NaN             NaN
# 26369                NaN         41.847224          NaN             NaN
# 26370                NaN         52.458334          NaN             NaN
# 26371                NaN               NaN          NaN             NaN
# 26372                NaN               NaN          NaN             NaN
#
#        Total_SAT_II  Obtained_SAT_II  NTS Merit Marks  \
# 0               NaN              NaN              NaN
# 1               NaN              NaN              NaN
# 2               NaN              NaN              NaN
# 3               NaN              NaN              NaN
# 4               NaN              NaN            66.91
# ...             ...              ...              ...
# 26368           NaN              NaN              NaN
# 26369           NaN              NaN              NaN
# 26370           NaN              NaN              NaN
# 26371           NaN              NaN              NaN
# 26372           NaN              NaN              NaN
#
#        BBA/BS(AF)_NU_Merit_Marks  BS_NU_Merit_Marks Campus Discipline  \
# 0                            NaN                NaN    NaN        NaN
# 1                            NaN                NaN    NaN        NaN
# 2                            NaN                NaN    NaN        NaN
# 3                            NaN              51.87    NaN        NaN
# 4                            NaN              51.50    NaN        NaN
# ...                          ...                ...    ...        ...
# 26368                        NaN                NaN    NaN        NaN
# 26369                        NaN              58.42    NaN        NaN
# 26370                        NaN              65.59    NaN        NaN
# 26371                        NaN                NaN    NaN        NaN
# 26372                        NaN                NaN    NaN        NaN
#
#       Campus_NU_Admission_Offer Discipline_NU_Admission_Offer  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           PWR                        BS(EE)
# 4                           NaN                           NaN
# ...                         ...                           ...
# 26368                       NaN                           NaN
# 26369                       NaN                           NaN
# 26370                       NaN                           NaN
# 26371                       NaN                           NaN
# 26372                       NaN                           NaN
#
#       Campus_Admission Discipline_Admission DEGREE_STATUS
# 0                  NaN                  NaN           NaN
# 1                  NaN                  NaN           NaN
# 2                  NaN                  NaN           NaN
# 3                  NaN                  NaN           NaN
# 4                  NaN                  NaN           NaN
# ...                ...                  ...           ...
# 26368              NaN                  NaN           NaN
# 26369              CFD           BS(CS)           Current
# 26370              ISB           BS(EE)           Current
# 26371              PWR           BS(EE)         Cancelled
# 26372              PWR           BS(EE)           Current
#
# [26373 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26373 entries, 0 to 26372
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   L                              26373 non-null  int64
#  1   CITY                           26373 non-null  object
#  2   STATUS_ID                      26373 non-null  int64
#  3   STATUS                         26373 non-null  object
#  4   1st_campus_pref                23760 non-null  object
#  5   2nd_campus_pref                811 non-null    object
#  6   3rd_campus_pref                125 non-null    object
#  7   4th_campus_pref                17 non-null     object
#  8   1st_discpline_pref             23766 non-null  object
#  9   2nd_discpline_pref             9931 non-null   object
#  10  3rd_discpline_pref             4648 non-null   object
#  11  4th_discpline_pref             1705 non-null   object
#  12  Board_Matriculation            25101 non-null  object
#  13  Degree_Matriculation           25101 non-null  object
#  14  Total_Matriculation            25101 non-null  float64
#  15  Obtained_Matriculation         25101 non-null  float64
#  16  Board_Intermediate             18876 non-null  object
#  17  Degree_Intermediate            18876 non-null  object
#  18  Total_Intermediate             18770 non-null  float64
#  19  Obtained_Intermediate          25101 non-null  float64
#  20  NTS_MARKS                      2860 non-null   float64
#  21  NU_TEST_CENTER                 15958 non-null  object
#  22  BBA_NU_Test_Marks              2879 non-null   float64
#  23  BS_NU_Test_Marks               14471 non-null  float64
#  24  Total_SAT_I                    313 non-null    float64
#  25  Obtained_SAT_I                 313 non-null    float64
#  26  Total_SAT_II                   202 non-null    float64
#  27  Obtained_SAT_II                202 non-null    float64
#  28  NTS Merit Marks                1429 non-null   float64
#  29  BBA/BS(AF)_NU_Merit_Marks      2865 non-null   float64
#  30  BS_NU_Merit_Marks              14435 non-null  float64
#  31  Campus                         404 non-null    object
#  32  Discipline                     404 non-null    object
#  33  Campus_NU_Admission_Offer      5973 non-null   object
#  34  Discipline_NU_Admission_Offer  5973 non-null   object
#  35  Campus_Admission               3611 non-null   object
#  36  Discipline_Admission           3611 non-null   object
#  37  DEGREE_STATUS                  3611 non-null   object
# dtypes: float64(14), int64(2), object(22)
# memory usage: 7.6+ MB

# %%
df.isnull().sum()
# Out:
# L                                    0
# CITY                                 0
# STATUS_ID                            0
# STATUS                               0
# 1st_campus_pref                   2613
# 2nd_campus_pref                  25562
# 3rd_campus_pref                  26248
# 4th_campus_pref                  26356
# 1st_discpline_pref                2607
# 2nd_discpline_pref               16442
# 3rd_discpline_pref               21725
# 4th_discpline_pref               24668
# Board_Matriculation               1272
# Degree_Matriculation              1272
# Total_Matriculation               1272
# Obtained_Matriculation            1272
# Board_Intermediate                7497
# Degree_Intermediate               7497
# Total_Intermediate                7603
# Obtained_Intermediate             1272
# NTS_MARKS                        23513
# NU_TEST_CENTER                   10415
# BBA_NU_Test_Marks                23494
# BS_NU_Test_Marks                 11902
# Total_SAT_I                      26060
# Obtained_SAT_I                   26060
# Total_SAT_II                     26171
# Obtained_SAT_II                  26171
# NTS Merit Marks                  24944
# BBA/BS(AF)_NU_Merit_Marks        23508
# BS_NU_Merit_Marks                11938
# Campus                           25969
# Discipline                       25969
# Campus_NU_Admission_Offer        20400
# Discipline_NU_Admission_Offer    20400
# Campus_Admission                 22762
# Discipline_Admission             22762
# DEGREE_STATUS                    22762
# dtype: int64

# %%
df.describe()
# Out:
#                   L     STATUS_ID  Total_Matriculation  \
# count  2.637300e+04  26373.000000         25101.000000
# mean   1.916158e+06      8.164183          1028.039241
# std    9.291715e+03      2.849937            98.317923
# min    1.900003e+06      1.000000             4.000000
# 25%    1.908146e+06      7.000000           900.000000
# 50%    1.915776e+06     10.000000          1100.000000
# 75%    1.924095e+06     10.000000          1100.000000
# max    1.932909e+06     10.000000          1700.000000
#
#        Obtained_Matriculation  Total_Intermediate  Obtained_Intermediate  \
# count            25101.000000        18770.000000           25101.000000
# mean               826.639720          630.185828             826.639720
# std                136.120088          226.520186             136.120088
# min                  0.000000            4.000000               0.000000
# 25%                720.000000          520.000000             720.000000
# 50%                842.000000          520.000000             842.000000
# 75%                940.000000          550.000000             940.000000
# max               1438.000000         3550.000000            1438.000000
#
#          NTS_MARKS  BBA_NU_Test_Marks  BS_NU_Test_Marks  Total_SAT_I  \
# count  2860.000000        2879.000000      14471.000000        313.0
# mean     44.682517          38.229632         36.099728       2400.0
# std      32.210655          12.638448         15.356976          0.0
# min       0.000000          -4.249992        -11.034722       2400.0
# 25%       0.000000          29.854173         24.958331       2400.0
# 50%      58.000000          38.666672         35.583333       2400.0
# 75%      71.000000          46.979170         46.902778       2400.0
# max      98.000000          74.375000         90.930552       2400.0
#
#        Obtained_SAT_I  Total_SAT_II  Obtained_SAT_II  NTS Merit Marks  \
# count      313.000000         202.0       202.000000      1429.000000
# mean      1076.167732         800.0       465.059406        71.554290
# std        463.373772           0.0       305.979491         7.538536
# min          0.000000         800.0         0.000000        50.580000
# 25%       1070.000000         800.0         0.000000        66.140000
# 50%       1200.000000         800.0       600.000000        71.750000
# 75%       1310.000000         800.0       677.500000        77.060000
# max       2400.000000         800.0       800.000000        92.510000
#
#        BBA/BS(AF)_NU_Merit_Marks  BS_NU_Merit_Marks
# count                2865.000000       14435.000000
# mean                   53.349326          54.167079
# std                     9.182330          11.097063
# min                    21.630000           6.610000
# 25%                    46.790000          46.100000
# 50%                    53.540000          54.080000
# 75%                    59.800000          62.050000
# max                    81.750000          91.430000

# %% [markdown]
# #

# %%
x = df.loc[(df["Total_Intermediate"] > df["Obtained_Intermediate"]) & (df["Total_Matriculation"] > df["Obtained_Matriculation"])]
x
# Out:
#              L          CITY  STATUS_ID              STATUS 1st_campus_pref  \
# 0      1900003    Rawalpindi          7     Challan Printed             ISB
# 3      1900007      Peshawar         10  Admit Card Printed             PWR
# 4      1900008     Islamabad         10  Admit Card Printed             ISB
# 11     1900015        Others          2        AcademicInfo             NaN
# 13     1900017     Islamabad          2        AcademicInfo             NaN
# ...        ...           ...        ...                 ...             ...
# 26368  1932905        Multan          7     Challan Printed             ISB
# 26369  1932906        Lahore         10  Admit Card Printed             ISB
# 26370  1932908  Bahawalnagar          9           Scheduled             ISB
# 26371  1932909      Peshawar         10  Admit Card Printed             PWR
# 26372  1932909      Peshawar         10  Admit Card Printed             PWR
#
#       2nd_campus_pref 3rd_campus_pref 4th_campus_pref 1st_discpline_pref  \
# 0                 NaN             NaN             NaN             BS(AF)
# 3                 NaN             NaN             NaN             BS(EE)
# 4                 NaN             NaN             NaN             BS(CS)
# 11                NaN             NaN             NaN                NaN
# 13                NaN             NaN             NaN                NaN
# ...               ...             ...             ...                ...
# 26368             NaN             NaN             NaN             BS(CS)
# 26369             NaN             NaN             NaN             BS(CS)
# 26370             NaN             NaN             NaN             BS(EE)
# 26371             NaN             NaN             NaN             BS(EE)
# 26372             NaN             NaN             NaN             BS(EE)
#
#       2nd_discpline_pref 3rd_discpline_pref 4th_discpline_pref  \
# 0                    NaN                NaN                NaN
# 3                 BS(CS)                NaN                NaN
# 4                    NaN                NaN                NaN
# 11                   NaN                NaN                NaN
# 13                   NaN                NaN                NaN
# ...                  ...                ...                ...
# 26368                NaN                NaN                NaN
# 26369                NaN                NaN                NaN
# 26370                NaN                NaN                NaN
# 26371                NaN                NaN                NaN
# 26372                NaN                NaN                NaN
#
#       Board_Matriculation Degree_Matriculation  Total_Matriculation  \
# 0               Cambridge              O-Level               1000.0
# 3                 Federal                  SSC               1050.0
# 4                 Federal                  SSC               1050.0
# 11                 Sukkur                  SSC                850.0
# 13              Cambridge              O-Level                  4.0
# ...                   ...                  ...                  ...
# 26368              Multan                  SSC               1100.0
# 26369           Cambridge              O-Level                900.0
# 26370          Bahawalpur                  SSC               1100.0
# 26371            Peshawar                  SSC               1100.0
# 26372            Peshawar                  SSC               1100.0
#
#        Obtained_Matriculation Board_Intermediate Degree_Intermediate  \
# 0                      900.00            Federal         HSSC (I+II)
# 3                      802.00            Federal         HSSC (I+II)
# 4                      728.00            Federal         HSSC (I+II)
# 11                     636.00        Mirpur Khas              HSSC-I
# 13                       3.51          Cambridge             A-Level
# ...                       ...                ...                 ...
# 26368                 1018.00             Multan         HSSC (I+II)
# 26369                  720.00          Cambridge             A-Level
# 26370                  924.00         Bahawalpur         HSSC (I+II)
# 26371                  918.00           Peshawar         HSSC (I+II)
# 26372                  918.00           Peshawar         HSSC (I+II)
#
#        Total_Intermediate  Obtained_Intermediate  NTS_MARKS NU_TEST_CENTER  \
# 0                  1050.0                 900.00        NaN            NaN
# 3                  1100.0                 802.00        NaN            ISB
# 4                  1100.0                 728.00       78.0            ISB
# 11                 1100.0                 636.00        NaN            NaN
# 13                    4.0                   3.51        NaN            NaN
# ...                   ...                    ...        ...            ...
# 26368              1100.0                1018.00        NaN            NaN
# 26369              1100.0                 720.00        NaN            LHR
# 26370              1100.0                 924.00        NaN            LHR
# 26371              1100.0                 918.00        NaN            NaN
# 26372              1100.0                 918.00        NaN            NaN
#
#        BBA_NU_Test_Marks  BS_NU_Test_Marks  Total_SAT_I  Obtained_SAT_I  \
# 0                    NaN               NaN          NaN             NaN
# 3                    NaN         30.291665          NaN             NaN
# 4                    NaN         47.187499          NaN             NaN
# 11                   NaN               NaN          NaN             NaN
# 13                   NaN               NaN          NaN             NaN
# ...                  ...               ...          ...             ...
# 26368                NaN               NaN          NaN             NaN
# 26369                NaN         41.847224          NaN             NaN
# 26370                NaN         52.458334          NaN             NaN
# 26371                NaN               NaN          NaN             NaN
# 26372                NaN               NaN          NaN             NaN
#
#        Total_SAT_II  Obtained_SAT_II  NTS Merit Marks  \
# 0               NaN              NaN              NaN
# 3               NaN              NaN              NaN
# 4               NaN              NaN            66.91
# 11              NaN              NaN              NaN
# 13              NaN              NaN              NaN
# ...             ...              ...              ...
# 26368           NaN              NaN              NaN
# 26369           NaN              NaN              NaN
# 26370           NaN              NaN              NaN
# 26371           NaN              NaN              NaN
# 26372           NaN              NaN              NaN
#
#        BBA/BS(AF)_NU_Merit_Marks  BS_NU_Merit_Marks Campus Discipline  \
# 0                            NaN                NaN    NaN        NaN
# 3                            NaN              51.87    NaN        NaN
# 4                            NaN              51.50    NaN        NaN
# 11                           NaN                NaN    NaN        NaN
# 13                           NaN                NaN    NaN        NaN
# ...                          ...                ...    ...        ...
# 26368                        NaN                NaN    NaN        NaN
# 26369                        NaN              58.42    NaN        NaN
# 26370                        NaN              65.59    NaN        NaN
# 26371                        NaN                NaN    NaN        NaN
# 26372                        NaN                NaN    NaN        NaN
#
#       Campus_NU_Admission_Offer Discipline_NU_Admission_Offer  \
# 0                           NaN                           NaN
# 3                           PWR                        BS(EE)
# 4                           NaN                           NaN
# 11                          NaN                           NaN
# 13                          NaN                           NaN
# ...                         ...                           ...
# 26368                       NaN                           NaN
# 26369                       NaN                           NaN
# 26370                       NaN                           NaN
# 26371                       NaN                           NaN
# 26372                       NaN                           NaN
#
#       Campus_Admission Discipline_Admission DEGREE_STATUS
# 0                  NaN                  NaN           NaN
# 3                  NaN                  NaN           NaN
# 4                  NaN                  NaN           NaN
# 11                 NaN                  NaN           NaN
# 13                 NaN                  NaN           NaN
# ...                ...                  ...           ...
# 26368              NaN                  NaN           NaN
# 26369              CFD           BS(CS)           Current
# 26370              ISB           BS(EE)           Current
# 26371              PWR           BS(EE)         Cancelled
# 26372              PWR           BS(EE)           Current
#
# [3564 rows x 38 columns]

# %%
y = x.loc[x["1st_discpline_pref"] != x["Discipline_Admission"]]
y
# Out:
#              L          CITY  STATUS_ID              STATUS 1st_campus_pref  \
# 0      1900003    Rawalpindi          7     Challan Printed             ISB
# 3      1900007      Peshawar         10  Admit Card Printed             PWR
# 4      1900008     Islamabad         10  Admit Card Printed             ISB
# 11     1900015        Others          2        AcademicInfo             NaN
# 13     1900017     Islamabad          2        AcademicInfo             NaN
# ...        ...           ...        ...                 ...             ...
# 26368  1932905        Multan          7     Challan Printed             ISB
# 26369  1932906        Lahore         10  Admit Card Printed             ISB
# 26370  1932908  Bahawalnagar          9           Scheduled             ISB
# 26371  1932909      Peshawar         10  Admit Card Printed             PWR
# 26372  1932909      Peshawar         10  Admit Card Printed             PWR
#
#       2nd_campus_pref 3rd_campus_pref 4th_campus_pref 1st_discpline_pref  \
# 0                 NaN             NaN             NaN             BS(AF)
# 3                 NaN             NaN             NaN             BS(EE)
# 4                 NaN             NaN             NaN             BS(CS)
# 11                NaN             NaN             NaN                NaN
# 13                NaN             NaN             NaN                NaN
# ...               ...             ...             ...                ...
# 26368             NaN             NaN             NaN             BS(CS)
# 26369             NaN             NaN             NaN             BS(CS)
# 26370             NaN             NaN             NaN             BS(EE)
# 26371             NaN             NaN             NaN             BS(EE)
# 26372             NaN             NaN             NaN             BS(EE)
#
#       2nd_discpline_pref 3rd_discpline_pref 4th_discpline_pref  \
# 0                    NaN                NaN                NaN
# 3                 BS(CS)                NaN                NaN
# 4                    NaN                NaN                NaN
# 11                   NaN                NaN                NaN
# 13                   NaN                NaN                NaN
# ...                  ...                ...                ...
# 26368                NaN                NaN                NaN
# 26369                NaN                NaN                NaN
# 26370                NaN                NaN                NaN
# 26371                NaN                NaN                NaN
# 26372                NaN                NaN                NaN
#
#       Board_Matriculation Degree_Matriculation  Total_Matriculation  \
# 0               Cambridge              O-Level               1000.0
# 3                 Federal                  SSC               1050.0
# 4                 Federal                  SSC               1050.0
# 11                 Sukkur                  SSC                850.0
# 13              Cambridge              O-Level                  4.0
# ...                   ...                  ...                  ...
# 26368              Multan                  SSC               1100.0
# 26369           Cambridge              O-Level                900.0
# 26370          Bahawalpur                  SSC               1100.0
# 26371            Peshawar                  SSC               1100.0
# 26372            Peshawar                  SSC               1100.0
#
#        Obtained_Matriculation Board_Intermediate Degree_Intermediate  \
# 0                      900.00            Federal         HSSC (I+II)
# 3                      802.00            Federal         HSSC (I+II)
# 4                      728.00            Federal         HSSC (I+II)
# 11                     636.00        Mirpur Khas              HSSC-I
# 13                       3.51          Cambridge             A-Level
# ...                       ...                ...                 ...
# 26368                 1018.00             Multan         HSSC (I+II)
# 26369                  720.00          Cambridge             A-Level
# 26370                  924.00         Bahawalpur         HSSC (I+II)
# 26371                  918.00           Peshawar         HSSC (I+II)
# 26372                  918.00           Peshawar         HSSC (I+II)
#
#        Total_Intermediate  Obtained_Intermediate  NTS_MARKS NU_TEST_CENTER  \
# 0                  1050.0                 900.00        NaN            NaN
# 3                  1100.0                 802.00        NaN            ISB
# 4                  1100.0                 728.00       78.0            ISB
# 11                 1100.0                 636.00        NaN            NaN
# 13                    4.0                   3.51        NaN            NaN
# ...                   ...                    ...        ...            ...
# 26368              1100.0                1018.00        NaN            NaN
# 26369              1100.0                 720.00        NaN            LHR
# 26370              1100.0                 924.00        NaN            LHR
# 26371              1100.0                 918.00        NaN            NaN
# 26372              1100.0                 918.00        NaN            NaN
#
#        BBA_NU_Test_Marks  BS_NU_Test_Marks  Total_SAT_I  Obtained_SAT_I  \
# 0                    NaN               NaN          NaN             NaN
# 3                    NaN         30.291665          NaN             NaN
# 4                    NaN         47.187499          NaN             NaN
# 11                   NaN               NaN          NaN             NaN
# 13                   NaN               NaN          NaN             NaN
# ...                  ...               ...          ...             ...
# 26368                NaN               NaN          NaN             NaN
# 26369                NaN         41.847224          NaN             NaN
# 26370                NaN         52.458334          NaN             NaN
# 26371                NaN               NaN          NaN             NaN
# 26372                NaN               NaN          NaN             NaN
#
#        Total_SAT_II  Obtained_SAT_II  NTS Merit Marks  \
# 0               NaN              NaN              NaN
# 3               NaN              NaN              NaN
# 4               NaN              NaN            66.91
# 11              NaN              NaN              NaN
# 13              NaN              NaN              NaN
# ...             ...              ...              ...
# 26368           NaN              NaN              NaN
# 26369           NaN              NaN              NaN
# 26370           NaN              NaN              NaN
# 26371           NaN              NaN              NaN
# 26372           NaN              NaN              NaN
#
#        BBA/BS(AF)_NU_Merit_Marks  BS_NU_Merit_Marks Campus Discipline  \
# 0                            NaN                NaN    NaN        NaN
# 3                            NaN              51.87    NaN        NaN
# 4                            NaN              51.50    NaN        NaN
# 11                           NaN                NaN    NaN        NaN
# 13                           NaN                NaN    NaN        NaN
# ...                          ...                ...    ...        ...
# 26368                        NaN                NaN    NaN        NaN
# 26369                        NaN              58.42    NaN        NaN
# 26370                        NaN              65.59    NaN        NaN
# 26371                        NaN                NaN    NaN        NaN
# 26372                        NaN                NaN    NaN        NaN
#
#       Campus_NU_Admission_Offer Discipline_NU_Admission_Offer  \
# 0                           NaN                           NaN
# 3                           PWR                        BS(EE)
# 4                           NaN                           NaN
# 11                          NaN                           NaN
# 13                          NaN                           NaN
# ...                         ...                           ...
# 26368                       NaN                           NaN
# 26369                       NaN                           NaN
# 26370                       NaN                           NaN
# 26371                       NaN                           NaN
# 26372                       NaN                           NaN
#
#       Campus_Admission Discipline_Admission DEGREE_STATUS
# 0                  NaN                  NaN           NaN
# 3                  NaN                  NaN           NaN
# 4                  NaN                  NaN           NaN
# 11                 NaN                  NaN           NaN
# 13                 NaN                  NaN           NaN
# ...                ...                  ...           ...
# 26368              NaN                  NaN           NaN
# 26369              CFD           BS(CS)           Current
# 26370              ISB           BS(EE)           Current
# 26371              PWR           BS(EE)         Cancelled
# 26372              PWR           BS(EE)           Current
#
# [3564 rows x 38 columns]

# %%
y["Discipline_Admission"].value_counts()
# Out:
# BS(CS)        308
# BS(EE)         93
# BBA            67
# BS(AF)         29
# BS(CV)         22
# BS(SE)         22
# BS(AI)         14
# BS(CSDF)       14
# BS(DS)         12
# Name: Discipline_Admission, dtype: int64

# %%
y["Discipline_Admission"].isnull().sum()
# Out:
# 2983

# %%
y["Discipline_Admission"] = y["Discipline_Admission"].fillna('No_Admission')

# %%
y["Discipline_Admission"].value_counts().plot(kind='bar',color='y', figsize = (20,20))
# Out:
# <AxesSubplot:>
